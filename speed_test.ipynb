# %%
import numpy as np
import time

size = 1000000
l1 = list(range(size))
l2 = list(range(size))

start = time.time()
add = [x + y for x, y in zip(l1, l2)]

end = time.time()
print(end - start)
# Out:
# 0.10227012634277344
